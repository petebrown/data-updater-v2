# %%
import json

with open('/Users/petebrown/Developer/data-updater-v2/bbc-json/lineups/2020-01-01.json') as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['homeTeam', 'awayTeam', 'useCatalogue', 'officials'])

# %%
teams = ['homeTeam', 'awayTeam']

# %%
data['homeTeam'].keys()
# Out:
# dict_keys(['id', 'urn', 'name', 'alignment', 'formation', 'manager', 'players'])

# %%
data['homeTeam']['players'].keys()
# Out:
# dict_keys(['starters', 'substitutes'])

# %%
import pandas as pd

starters = data['homeTeam']['players']['starters']

starters_df = []

for s in starters:
    starters_df.append(pd.DataFrame.from_dict(s, orient='index').T)
starters_df = pd.concat(starters_df, ignore_index=True)

starter_names = pd.json_normalize(starters_df['name'])

pd.concat([starters_df, starter_names], axis=1)
# Out:
#                                                   urn  \
# 0   urn:bbc:sportsdata:football:player:s-c9vek5ubp...
# 1   urn:bbc:sportsdata:football:player:s-1a8msufvk...
# 2   urn:bbc:sportsdata:football:player:s-eabj99pro...
# 3   urn:bbc:sportsdata:football:player:s-2uwn00y18...
# 4   urn:bbc:sportsdata:football:player:s-3gffyf2cg...
# 5   urn:bbc:sportsdata:football:player:s-cc1ub1b70...
# 6   urn:bbc:sportsdata:football:player:s-dcu4iqh29...
# 7   urn:bbc:sportsdata:football:player:s-7qnu4sb2a...
# 8   urn:bbc:sportsdata:football:player:s-7xr6yeu0y...
# 9   urn:bbc:sportsdata:football:player:s-1uer7zbsj...
# 10  urn:bbc:sportsdata:football:player:s-4qrvri86m...
#
#                                                  name              position  \
# 0   {'short': 'A. Chapman', 'first': 'Aaron James'...            Goalkeeper
# 1   {'short': 'C. Woods', 'first': 'Calum Jack', '...              Defender
# 2   {'short': 'G. Ray', 'first': 'George Edward', ...              Defender
# ...

# %%
cards = starters_df.cards

for c in cards:
    if c:
        print(pd.json_normalize(c))
    

pd.json_normalize(cards)
# Out:
#           type timeLabel.value timeLabel.accessible
# 0  Yellow Card             24'           24 minutes
#                                                     0
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   {'type': 'Yellow Card', 'timeLabel.value': '24...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None

# %%
subs = starters_df.substitutes

for s in subs:
    if s:
        print(pd.json_normalize(s))
# Out:
#                                    playerSubbedOutId  \
# 0  urn:bbc:sportsdata:football:player:s-4qrvri86m...
#
#                                     playerSubbedInId playerSubbedInName  \
# 0  urn:bbc:sportsdata:football:player:s-dedo3aeuf...          P. Mullin
#
#   timeLabel.value timeLabel.accessible
# 0             70'           70 minutes

# %%
subbed_off = starters_df.substitutedOff

pd.json_normalize(subbed_off)
# Out:
#     periodId  timeMin timeMinSec             timestamp  \
# 0        NaN      NaN        NaN                   NaN
# 1        NaN      NaN        NaN                   NaN
# 2        NaN      NaN        NaN                   NaN
# 3        NaN      NaN        NaN                   NaN
# 4        NaN      NaN        NaN                   NaN
# 5        NaN      NaN        NaN                   NaN
# 6        NaN      NaN        NaN                   NaN
# 7        NaN      NaN        NaN                   NaN
# 8        NaN      NaN        NaN                   NaN
# 9        NaN      NaN        NaN                   NaN
# 10       2.0     70.0      69:32  2020-01-01T16:28:00Z
#
#                                           playerOnUrn playerOnName    reason
# 0                                                 NaN          NaN       NaN
# 1                                                 NaN          NaN       NaN
# ...

# %%
import pandas as pd

pd.json_normalize(p)
# Out:
#                                                  urn    position  shirtNumber  \
# 0  urn:bbc:sportsdata:football:player:s-c9vek5ubp...  Goalkeeper           31
#
#   formationPlace  isCaptain cards displayName substitutes  name.short  \
# 0              1      False    []  A. Chapman          []  A. Chapman
#
#     name.first name.last
# 0  Aaron James   Chapman

# %%
s = []

for starter in data['homeTeam']['players']['starters']:
    s.append(pd.json_normalize(starter))

# %%
s[4]
# Out:
#                                                  urn    position  shirtNumber  \
# 0  urn:bbc:sportsdata:football:player:s-3gffyf2cg...  Midfielder            7
#
#   formationPlace  isCaptain  \
# 0              3      False
#
#                                                cards displayName substitutes  \
# 0  [{'type': 'Yellow Card', 'timeLabel': {'value'...   K. Morris          []
#
#   name.short name.first name.last card.type.value card.type.accessibleValue  \
# 0  K. Morris     Kieron    Morris          yellow               Yellow Card
#
#   card.time.value card.time.accessibleValue
# 0             24'                24 minutes
